# %%
import librosa
import IPython.display as ipd

# %%
fake_audio = 'E:/_Учёба/Мага_Диплом/DSP/libs/librosa/audio/file12.wav_16k.wav_norm.wav_mono.wav_silence.wav'
ipd.Audio(fake_audio)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
fake_audio, sr = librosa.load(fake_audio, sr=44100)
librosa.display.waveshow(fake_audio)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 fake_audio, sr = librosa.load(fake_audio, sr=44100)
#       2 librosa.display.waveshow(fake_audio)
#
# File c:\Users\Кирилл СеверСнаб\AppData\Local\Programs\Python\Python313\Lib\site-packages\librosa\core\audio.py:176, in load(path, sr, mono, offset, duration, dtype, res_type)
#     173 else:
#     174     # Otherwise try soundfile first, and then fall back if necessary
#     175     try:
# --> 176         y, sr_native = __soundfile_load(path, offset, duration, dtype)
#     178     except sf.SoundFileRuntimeError as exc:
#     179         # If soundfile failed, try audioread instead
#     180         if isinstance(path, (str, pathlib.PurePath)):
#
# ...
